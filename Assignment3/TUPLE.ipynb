# %% [markdown]
# **TUPLE**:To store multiple items in a single variable.
#           :unchangeable

# %%
Royalenfield=("GT650","Hunter350","Meteor","Classic350")
print(Royalenfield)
# Out:
# ('GT360', 'Hunter350', 'Meteor', 'Classic350')

# %% [markdown]
# **TUPLE** allow dublicate values

# %%
Royalenfield=("GT650","Hunter350","Meteor","Classic350","GT650","Hunter350")
print(Royalenfield)
# Out:
# ('GT360', 'Hunter350', 'Meteor', 'Classic350', 'GT360', 'Hunter350')

# %% [markdown]
# **TUPLE** LENGTH:

# %%
Royalenfield=("GT650","Hunter350","Meteor","Classic350")
print(len(Royalenfield))
# Out:
# 4

# %% [markdown]
# **TUPLE** can be of any data type:

# %%
Royalenfield=("GT650","Hunter350","Meteor","Classic350")
print(Royalenfield)
Number=(1, 2, 3, 4, 5)
print(Number)
Bool=(True,False,True)
print(Bool)
# Out:
# ('GT360', 'Hunter350', 'Meteor', 'Classic350')
# (1, 2, 3, 4, 5)
# (True, False, True)

# %% [markdown]
# **TUPLE()** constructor

# %%
Royalenfield=tuple(("GT650","Hunter350","Meteor","Classic350"))
print(Royalenfield)
# Out:
# ('GT360', 'Hunter350', 'Meteor', 'Classic350')

# %% [markdown]
# Add Items:

# %%
SRoyalenfield=("GT650","Hunter350","Meteor","Classic350")
x=list(Royalenfield)
x.append("Himalayan")
Royalenfield=tuple(x)
print(Royalenfield)
# Out:
# ('GT650', 'Hunter350', 'Meteor', 'Classic350', 'Himalayan')

# %% [markdown]
# Remove items:

# %%
Royalenfield=("GT650","Hunter350","Meteor","Classic350")
x=list(Royalenfield)
x.remove("Meteor")
Royalenfield=tuple(x)
print(Royalenfield)
# Out:
# ('GT650', 'Hunter350', 'Classic350')

# %% [markdown]
# **SOME EXAMPLES OF TUPLES**

# %% [markdown]
# CHECK "**Meteor**" exists in a tuple

# %%
Royalenfield=("GT650","Hunter350","Meteor","Classic350")
if "Meteor" in Royalenfield:
    print("Meteor found")
else:
    print("Meteor Not Found")
# Out:
# Meteor found

# %% [markdown]
# **REVERSING** the TUPLE

# %%
numbers = (10, 20, 30, 40, 50)
print("Original Tuple:", numbers)
print("Reversed Tuple:", numbers[::-1])
# Out:
# Original Tuple: (10, 20, 30, 40, 50)
# Reversed Tuple: (50, 40, 30, 20, 10)

# %% [markdown]
# **COUNTING** the number appearence

# %%
numbers = (10,20,10,30,10,40)
count = numbers.count(10)
print("10 appears",count,"times.")
# Out:
# 10 appears 3 times.
